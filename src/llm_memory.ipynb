# %%
from langchain_ollama import ChatOllama

# %%
llm=ChatOllama(model="llama3.1:8b")

# %%
llm.invoke("my name is anthony gonzales").content
# Out:
# "Hello Anthony Gonzales! It's nice to meet you. What brings you here today? Do you have any questions or topics you'd like to discuss? I'm all ears!"

# %%
llm.invoke("what is my name ").content
# Out:
# "Unfortunately, I don't have any information about your personal details or name. I'm a text-based AI assistant and our conversation just started, so I don't know anything about you yet! Would you like to introduce yourself?"

# %%
messages=['my name is anthony gonzales']

# %%
output=llm.invoke(messages).content

# %%
messages.append(output)

# %%
messages
# Out:
# ['my name is anthony gonzales',
#  'Nice to meet you, Anthony Gonzales! Is there something I can help you with today?']

# %%
messages.append("what is my name")

# %%
output=llm.invoke(messages)

# %%
output.content
# Out:
# 'Your name is Anthony Gonzales.'
